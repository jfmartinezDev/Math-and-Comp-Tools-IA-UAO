# %% [markdown]
# #**Graficos utilizando la libreria Matplotlib**

# %%
import matplotlib as plt
import numpy as np

# %% [markdown]
# cuando se utilizan los notebooks es mas practico visualizar los graficos dentro del mismo note. Para esto es necesario incluir la instruccion %matplotlib inline

# %%
# %matplotlib inline

# %% [markdown]
# ##**Primer grafico**

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 4, 9, 5, 3])
plt.show()

# %% [markdown]
# * **plot** es la funcion encargada de contruir el grafico
# *  **show** es la funcion que permite mostrar el grafico
#
# * la funcion **plot** recibe los datos en forma de vector

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.show()

# %% [markdown]
# El primer vector o parametro de la funcion plot hace referencia al eje horizontal del grafico. El segundo especifica el eje vertical

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.axis([-4, 6, 0, 7])
plt.show()

# %% [markdown]
# la funcion **axis** permite configurar el tamaño de los ejes del grafico

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
#print(x)
y = x**2

plt.plot(x, y)
plt.show()

# %% [markdown]
# **Graficar Vectores**

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.quiver([0, 0], [0, 0], [1, -2], [1, 2], angles='xy', scale_units='xy', scale=1)
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.show()

# %% [markdown]
# A continuacion se agregaran un titulo, los nombres de los y una grilla o cuadricula.

# %%
plt.plot(x, y)
plt.title("Square function")
plt.xlabel("x")
plt.ylabel(r'$x^2$')
plt.grid(True)
plt.show()

# %% [markdown]
# # **Estilo y Corlor**
#
# por defecto, matlplotlib dibuja una linea entre puntos consecutivos

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], [0, 0, 100, 100, 0, 100, 130, 100, 0])
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# existe un tercer argumento o parametro, el cual indica el color y el estilo de la linea del grafico

# %%
plt.plot([0, 100, 100, 0, 0, 100, 50, 0, 100], [0, 0, 100, 100, 0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# es posible graficar lineas con diferente estilo dentro de un mismo grafico.

# %%
plt.plot([0, 100, 100, 0, 0], [0, 0, 100, 100, 0], "r-", [0, 100, 50, 0, 100], [0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# una forma mas ordenada se graficar varios datos en un mismo grafico se muestra a continuacion

# %%
plt.plot([0, 100, 100, 0, 0], [0, 0, 100, 100, 0], "r-")
plt.plot([0, 100, 50, 0, 100], [0, 100, 130, 100, 0], "g--")
plt.axis([-10, 110, -10, 140])
plt.show()

# %% [markdown]
# en lugar de dibujar lineas, es posible graficar los datos utilizando puntos con diferente forma y color

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x, 'g--', x, x**2, 'r:', x, x**3, 'b^')
plt.show()

# %% [markdown]
# existes un gran numero de atributos que se pueden modficar para logar una apariencia deseada en el grafico

# %%
x = np.linspace(-1.4, 1.4, 30)
line1, line2, line3 = plt.plot(x, x, 'g--', x, x**2, 'r:', x, x**3, 'b^')
line1.set_linewidth(3.0)
line1.set_dash_capstyle("round")
line3.set_alpha(0.2)
plt.show()

# %% [markdown]
# ## **Guardar la figura**
#
# la funcion savefig permite guardar la figura en un formato de imagen que por lo general es png

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.plot(x, x**2)
plt.savefig("my_square_function.png", transparent=True)

# %% [markdown]
# ## **Dibujar varios graficos en una misma figura (Subplots)**
#
# * Para crear una figura con multiples graficos se utiliza la funcion **subplot**, la cual permite organizar dichos graficos en una cuadricula (grid).
#
# * La funcion subplot recibe como parametros la cantidad de filas y columnas de la figura y el indice de la grafica que se desea dibujar en dicha posicion.
#
# * Las posiciones se indican de izquierda a derecha y de arriba a abajo.

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot = bottow left
plt.plot(x, x**3)
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot = bottom right
plt.plot(x, x**4)
plt.show()

# %% [markdown]
# Algunos graficos necesitan extenderse por mas de una posicion en la cuadricula

# %%
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 1, 2)  # 2 rows, *1* column, 2nd subplot = bottom
plt.plot(x, x**3)
plt.show()

# %% [markdown]
# para posicionar graficos dentro de una misma figura de una forma mas compleja, se puede utilizar la funcion **subplot2gird**. En este caso se deben especificar el numero de filas y columnas en la cuadricula, la position de la grafica dentro de la cuadricula, y opcionalmente cuantas filas y columnas ocupara dicha grafica.

# %%
plt.subplot2grid((3,3), (0, 0), rowspan=2, colspan=2)
plt.plot(x, x**2)
plt.subplot2grid((3,3), (0, 2))
plt.plot(x, x**3)
plt.subplot2grid((3,3), (1, 2), rowspan=2)
plt.plot(x, x**4)
plt.subplot2grid((3,3), (2, 0), colspan=2)
plt.plot(x, x**5)
plt.show()

# %% [markdown]
# ## **Multiples Figuras**
#
# la funcion **figure** permite crear diferentes figuras que pueden contener diferentes graficos. Esto es util cuando se quieren guardar graficos en diferentes figuras.

# %%
x = np.linspace(-1.4, 1.4, 30)

plt.figure(1)
plt.subplot(211)
plt.plot(x, x**2)
plt.title("Square and Cube")
plt.subplot(212)
plt.plot(x, x**3)

plt.figure(2, figsize=(10, 5))
plt.subplot(121)
plt.plot(x, x**4)
plt.title("y = x**4")
plt.subplot(122)
plt.plot(x, x**5)
plt.title("y = x**5")

plt.figure(1)      # back to figure 1, current subplot is 212 (bottom)
plt.plot(x, -x**3, "r:")

plt.show()

# %% [markdown]
# Existe una forma mas interactiva para crear graficos sin necesidad de utilizar siempre la funcion plot. Pero recordar que una de las filosofias de Python es "explicito es mejor que implicito"

# %%
x = np.linspace(-2, 2, 200)
fig1, (ax_top, ax_bottom) = plt.subplots(2, 1, sharex=True)
fig1.set_size_inches(10,5)
line1, line2 = ax_top.plot(x, np.sin(3*x**2), "r-", x, np.cos(5*x**2), "b-")
line3, = ax_bottom.plot(x, np.sin(3*x), "r-")
ax_top.grid(True)

fig2, ax = plt.subplots(1, 1)
ax.plot(x, x**2)
plt.show()

# %% [markdown]
# # **Insertar texto en los graficos**

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px**2

plt.plot(x, x**2, "b-", px, py, "ro")

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='blue', horizontalalignment="center")
plt.text(px - 0.08, py, "Beautiful point", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny = %0.2f"%(px, py), rotation=50, color='gray')

plt.show()

# %% [markdown]
# La funcion ***annotate*** permite insertar anotaciones dentro de un grafico

# %%
plt.plot(x, x**2, px, py, "ro")
plt.annotate("Beautiful point", xy=(px, py), xytext=(px-1.3,py+0.5),
                           color="green", weight="heavy", fontsize=14,
                           arrowprops={"facecolor": "lightgreen"})
plt.show()

# %% [markdown]
# Es posible agregar mas efectos o formas al texto dentro de un grafico

# %%
plt.plot(x, x**2, px, py, "ro")

bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
plt.text(px-0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=5)
plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='black', ha="center", bbox=bbox_props)

plt.show()

# %% [markdown]
# # **leyendas (legends)**
#
# para insertar leyendas en los graficos, primero se deben definir las etiquetas (labels)

# %%
x = np.linspace(-1.4, 1.4, 50)
plt.plot(x, x**2, "r--", label="Square function")
plt.plot(x, x**3, "g-", label="Cube function")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Escala de los ejes**
#
# Matplotlib permite escala no lineal en los ejes de los graficos, como por ejemplo la escala logaritmica

# %%
x = np.linspace(0.1, 15, 500)
y = x**3/np.exp(2*x)

plt.figure(1)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

plt.figure(2)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

plt.figure(3)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)

plt.figure(4)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.05)
plt.title('symlog')
plt.grid(True)

plt.show()

# %% [markdown]
# # **Configuraciones sobre los ejes, lineas y los labels**
#
# Los ejes tienen una serie de atributos llamados "ticks". Existen otros atributos llamados "tickers" que se encargan de decidir donde posicionar los ticks

# %%
x = np.linspace(-2, 2, 100)

plt.figure(1, figsize=(15,10))
plt.subplot(131)
plt.plot(x, x**3)
plt.grid(True)
plt.title("Default ticks")

ax = plt.subplot(132)
plt.plot(x, x**3)
ax.xaxis.set_ticks(np.arange(-2, 2, 1))
plt.grid(True)
plt.title("Manual ticks on the x-axis")

ax = plt.subplot(133)
plt.plot(x, x**3)
plt.minorticks_on()
ax.tick_params(axis='x', which='minor', bottom='off')
ax.xaxis.set_ticks([-2, 0, 1, 2])
ax.yaxis.set_ticks(np.arange(-5, 5, 1))
ax.yaxis.set_ticklabels(["min", -4, -3, -2, -1, 0, 1, 2, 3, "max"])
plt.title("Manual ticks and tick labels\n(plus minor ticks) on the y-axis")

plt.grid(True)

plt.show()

# %% [markdown]
# # **Graficos Polares**
#
# Para generar un grafico polar se debe asignar al atributo "projection" el valor 'polar'

# %%
radius = 1
theta = np.linspace(0, 2*np.pi*radius, 1000)

plt.subplot(111, projection='polar')
plt.plot(theta, np.sin(5*theta), "g-")
plt.plot(theta, 0.5*np.cos(20*theta), "b-")
plt.show()

# %% [markdown]
# # **Graficos en 3D**
#
# Para realizar graficos en 3D se necesita importar **Axes3D**. Luego se debe crear un subplot configurando el atributo "projection" como 3d. Esto retorna un objeto **Axes3DSubplot** el cual puede ser usado llamadno la funcion **plot_surface**

# %%
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %% [markdown]
# Otra forma de visualizar una gradica en 3D es por medio de la funcion **contour**

# %%
plt.contourf(X, Y, Z, cmap=matplotlib.cm.coolwarm)
plt.colorbar()
plt.show()

# %% [markdown]
# **Vectores en R3**

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

p0 = [0.799319, -3.477045e-01, 0.490093]
p1 = [0.852512, 9.113778e-16, -0.522708]
p2 = [0.296422, 9.376042e-01, 0.181748]

origin = [0,0,0]
X, Y, Z = zip(origin,origin,origin) 
U, V, W = zip(p0,p1,p2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X,Y,Z,U,V,W,arrow_length_ratio=0.01)
plt.show()

# %% [markdown]
# # **Graficar la relacion entre dos conjuntos de datos (Scatter Plots)**

# %%
from numpy.random import rand
x, y = rand(2, 5)
print(x)
print(y)
plt.scatter(x, y)
plt.show()
# Out:
# [0.75288204 0.79569513 0.3593869  0.81772921 0.72403862]
# [0.6478698  0.64414632 0.40997845 0.06940149 0.28785137]

# %% [markdown]
# Es posible modificar la apariencia de cada punto dentro del grafico

# %%
x, y, scale = rand(3, 100)
scale = 500 * scale ** 5
plt.scatter(x, y, s=scale)
plt.show()

# %% [markdown]
# Como en los ejemplos anteriores, existen otros atriburos para modificar la apariencia del grafico.

# %%
for color in ['red', 'green', 'blue']:
    n = 100
    x, y = rand(2, n)
    scale = 500.0 * rand(n) ** 5
    plt.scatter(x, y, s=scale, c=color, alpha=0.3, edgecolors='blue')

plt.grid(True)

plt.show()

# %% [markdown]
# # **Dibujar Lineas sobre los graficos**

# %%
from numpy.random import randn

def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

x = randn(1000)
y = 0.5*x + 5 + randn(1000)*2
plt.axis([-2.5, 2.5, -5, 15])
plt.scatter(x, y, alpha=0.2)
plt.plot(1, 0, "ro")
plt.vlines(1, -5, 0, color="red")
plt.hlines(0, -2.5, 1, color="red")
plot_line(axis=plt.gca(), slope=0.5, intercept=5, color="magenta")
plt.grid(True)
plt.show()

# %% [markdown]
# # **Histogramas**
#
# Un histograma es un grafico que permite visualizar un conjunto de datos mediante barras de diferentes alturas. Cada barra es definida por un rango de valores (ancho) y la altura. Las barras de mayor altura indican que la mayoria de los datos se encuentran en su rango.

# %%
data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3]
plt.subplot(211)
plt.hist(data, bins = 10, rwidth=0.8)

plt.subplot(212)
plt.hist(data, bins = [1, 1.5, 2, 2.5, 3], rwidth=0.95)
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
data1 = np.random.randn(400)
data2 = np.random.randn(500) + 3
data3 = np.random.randn(450) + 6
data4a = np.random.randn(200) + 9
data4b = np.random.randn(100) + 10

plt.hist(data1, bins=5, color='g', alpha=0.75, label='bar hist') # default histtype='bar'
plt.hist(data2, color='b', alpha=0.65, histtype='stepfilled', label='stepfilled hist')
plt.hist(data3, color='r', histtype='step', label='step hist')
plt.hist((data4a, data4b), color=('r','m'), alpha=0.55, histtype='barstacked', label=('barstacked a', 'barstacked b'))

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # **Graficar Imagenes**
#
# Para leer una imagen se debe importar **matplotlib.image** y utilizar la funcion **imread** con el nombre del archivo como parametro. Esta funcion returna los datos de la imagen en formato de **NumPy array**.

# %%
import matplotlib.image as mpimg

img = mpimg.imread('my_square_function.png')
print(img.shape, img.dtype)
# Out:
# (288, 432, 4) float32

# %% [markdown]
# La imagen cargada tiene 288x432 pixels. Cada pixel esta representado por 4 elementos: rojo, verde, azul, nivel de alpha. Todo se encuentra almacenado en formato float de 32 bits con valores entre 0 y 1.
#
# Para visualizar la imagen se utiliza la funcion **imshow**

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# Para ocultar los ejes de la figura:

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# De esta manera es facil generar una figura propia

# %%
img = np.arange(100*100).reshape(100, 100)
print(img)
plt.imshow(img)
plt.show()
# Out:
# [[   0    1    2 ...   97   98   99]
#  [ 100  101  102 ...  197  198  199]
#  [ 200  201  202 ...  297  298  299]
#  ...
#  [9700 9701 9702 ... 9797 9798 9799]
#  [9800 9801 9802 ... 9897 9898 9899]
#  [9900 9901 9902 ... 9997 9998 9999]]

# %%
plt.imshow(img, cmap="hot")
plt.show()

# %% [markdown]
# Es posible generar una imagen directamente

# %%
img = np.empty((20,30,3))
img[:, :10] = [0, 0, 0.6]
img[:, 10:20] = [1, 1, 1]
img[:, 20:] = [0.6, 0, 0]
plt.imshow(img)
plt.show()

# %% [markdown]
# # **Animaciones**

# %%
# %matplotlib inline

from matplotlib import animation, rc
from IPython.display import HTML

x = np.linspace(-1, 1, 100)
y = np.sin(x**2*25)
data = np.array([x, y])

fig = plt.figure()
line, = plt.plot([], [], "r-") # start with an empty plot
plt.axis([-1.1, 1.1, -1.1, 1.1])
plt.plot([-0.5, 0.5], [0, 0], "b-", [0, 0], [-0.5, 0.5], "b-", 0, 0, "ro")
plt.grid(True)
plt.title("Marvelous animation")

# this function will be called at every iteration
def update_line(num, data, line):
    line.set_data(data[..., :num] + np.random.rand(2, num) / 25)  # we only plot the first `num` data points.
    return line,

line_ani = animation.FuncAnimation(fig, update_line, frames=100, fargs=(data, line), interval=67)
plt.show()



HTML(line_ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # **Guardar Animaciones en Archivos de video**

# %%
Writer = animation.writers['ffmpeg']
writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)
line_ani.save('my_wiggly_animation.mp4', writer=writer)

# %% [markdown]
# #**References**
#
# * https://matplotlib.org/index.html
#
# * Géron, Aurélien. Hands-On Machine Learning with Scikit-Learn, Keras, and
# TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems. O'Reilly Media, 2019.

# %% [markdown]
# ## **Ejercicios**

# %% [markdown]
# 1. De un experimento se tomaron las siguientes valores:
#
# ![Tabla Valores](http://rsefalicante.umh.es/LaboratorioMateria/PV/boyle-tabla-2010.PNG)
#
# Realice una grafica de la variación de la presión al cambiar el volumen

# %%
v = np.linspace(34,52,10)
p = np.array([1.5086,1.425,1.3539,1.2806,1.22,1.1610,1.1149,1.0664,1.026,0.985])
plt.plot(v, p)
plt.show()

# %% [markdown]
# 2. La solución de una ecuación diferencial esta dada por la siguiente ecuación
# y(t)=C-exp(-r*t)
# Grafique la respuesta del sistema con C=5 y r=2

# %%
t=np.linspace(0, 5, 100)
y=5-np.exp(-2*t)
plt.pyplot.plot(t, y)
plt.pyplot.show()

# %% [markdown]
# 3. La solución de una ecuación diferencial esta dada por la siguiente ecuación
# y(t)=C-exp(-r*t)
# Grafique la respuesta del sistema con C=5 y r con valores de 1 a 5

# %%
t=np.linspace(0, 5, 100)
yt= np.zeros((5,100))
for i in range(1,5):
  yt[i,:]=5-np.exp(-i*t)

for i in range(1,5):
  plt.pyplot.plot(t,yt[i,:])
  plt.pyplot.show()

# %% [markdown]
# 4. Simular la siguiente ecuación W(k+1)=W(k)+p DW(k) que implementa el proceso de entrenamiento de una red neuronal artificial durante 100 iteraciones. Suponga p=0.9 y Dw(k)= valor randómico

# %%
W= np.zeros((100,1))
for k in range(0,99):
  W[k+1]=W[k]+0.9*np.random.randn()

plt.pyplot.plot(W)
plt.pyplot.show()

# %% [markdown]
# 5. Realizar algún ejercicio con manipulación de imágenes cargándolas como matrices en numpy

# %%
import matplotlib.image as mpimg

img = mpimg.imread('index.jpeg')
print(img.shape, img.dtype)
# Out:
# (183, 275, 3) uint8

# %%
plt.pyplot.imshow(img)
plt.pyplot.show()

# %%
plt.pyplot.imshow(img)
plt.pyplot.axis('off')
plt.pyplot.show()

# %%
r=np.zeros(img.shape, dtype="uint8")
r[:,:,0]=img[:,:,0]
plt.pyplot.imshow(r)

# %%
g=np.zeros(img.shape, dtype="uint8")
g[:,:,1]=img[:,:,1]
plt.pyplot.imshow(g)

# %%
b=np.zeros(img.shape, dtype="uint8")
b[:,:,2]=img[:,:,2]
plt.pyplot.imshow(b)
